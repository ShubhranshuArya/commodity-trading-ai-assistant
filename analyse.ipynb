# %%
# Ignore warnings
import warnings
warnings.filterwarnings('ignore')

# Import Path from pathlib
from pathlib import Path

# Import yfinance package
import yfinance as yf

# Import pandas package
import pandas as pd

# %%
# Pull the data for the first security
stock_data_1 = yf.Ticker("NG=F")
stock_data_1.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 4,
#  'previousClose': 3.948,
#  'open': 3.815,
#  'dayLow': 3.756,
#  'dayHigh': 3.864,
#  'regularMarketPreviousClose': 3.948,
#  'regularMarketOpen': 3.815,
#  'regularMarketDayLow': 3.756,
#  'regularMarketDayHigh': 3.864,
#  'volume': 49701,
#  'regularMarketVolume': 49701,
#  'averageVolume': 186060,
#  'averageVolume10days': 184895,
#  'averageDailyVolume10Day': 184895,
#  'bid': 3.801,
#  'ask': 3.803,
#  'askSize': 1000,
#  'expireDate': 1738108800,
#  'openInterest': 92451,
#  'fiftyTwoWeekLow': 1.481,
#  'fiftyTwoWeekHigh': 4.369,
#  'fiftyDayAverage': 3.32982,
#  'twoHundredDayAverage': 2.580755,
#  'currency': 'USD',
#  'exchange': 'NYM',
#  'quoteType': 'FUTURE',
#  'symbol': 'NGG25.NYM',
#  'underlyingSymbol': 'NG=F',
#  'shortName': 'Natural Gas Feb 25',
#  'firstTradeDateEpochUtc': 967608000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '2a316c73-eccf-333d-b201-8205e14254ed',
#  'gmtOffSetMilliseconds': -18000000,
#  'trailingPegRatio': None}

# %%
stock_data_2 = yf.Ticker("GC=F")
stock_data_2.info
# Out:
# {'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 2748.7,
#  'open': 2739.6,
#  'dayLow': 2715.6,
#  'dayHigh': 2754.8,
#  'regularMarketPreviousClose': 2748.7,
#  'regularMarketOpen': 2739.6,
#  'regularMarketDayLow': 2715.6,
#  'regularMarketDayHigh': 2754.8,
#  'volume': 121225,
#  'regularMarketVolume': 121225,
#  'averageVolume': 5504,
#  'averageVolume10days': 881,
#  'averageDailyVolume10Day': 881,
#  'bid': 2733.2,
#  'ask': 2733.4,
#  'bidSize': 1400,
#  'askSize': 800,
#  'expireDate': 1740528000,
#  'openInterest': 287252,
#  'fiftyTwoWeekLow': 1984.8,
#  'fiftyTwoWeekHigh': 2789.0,
#  'fiftyDayAverage': 2647.916,
#  'twoHundredDayAverage': 2504.0625,
#  'currency': 'USD',
#  'exchange': 'CMX',
#  'quoteType': 'FUTURE',
#  'symbol': 'GCG25.CMX',
#  'underlyingSymbol': 'GC=F',
#  'shortName': 'Gold Feb 25',
#  'firstTradeDateEpochUtc': 967608000,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '14f8f2ec-b820-38f7-ba5f-b3f5a47aec05',
#  'gmtOffSetMilliseconds': -18000000,
#  'trailingPegRatio': None}

# %%
stock_data_1.history(period="2y", interval="1d")
# Out:
#                             Open   High    Low  Close  Volume  Dividends  \
# Date
# 2023-01-20 00:00:00-05:00  3.203  3.389  3.091  3.174  106735        0.0
# 2023-01-23 00:00:00-05:00  3.450  3.564  3.243  3.447  130377        0.0
# 2023-01-24 00:00:00-05:00  3.450  3.595  3.224  3.258   62585        0.0
# 2023-01-25 00:00:00-05:00  3.242  3.251  2.992  3.067   40750        0.0
# 2023-01-26 00:00:00-05:00  3.003  3.003  2.761  2.944   47669        0.0
# ...                          ...    ...    ...    ...     ...        ...
# 2025-01-10 00:00:00-05:00  3.709  4.018  3.685  3.989  229112        0.0
# 2025-01-13 00:00:00-05:00  4.347  4.369  3.845  3.934  195514        0.0
# 2025-01-14 00:00:00-05:00  3.930  4.059  3.736  3.968  167416        0.0
# 2025-01-15 00:00:00-05:00  3.955  4.141  3.859  4.083  167416        0.0
# 2025-01-20 00:00:00-05:00  3.815  3.864  3.756  3.801   50985        0.0
#
#                            Stock Splits
# Date
# 2023-01-20 00:00:00-05:00           0.0
# 2023-01-23 00:00:00-05:00           0.0
# 2023-01-24 00:00:00-05:00           0.0
# 2023-01-25 00:00:00-05:00           0.0
# 2023-01-26 00:00:00-05:00           0.0
# ...                                 ...
# 2025-01-10 00:00:00-05:00           0.0
# 2025-01-13 00:00:00-05:00           0.0
# 2025-01-14 00:00:00-05:00           0.0
# 2025-01-15 00:00:00-05:00           0.0
# 2025-01-20 00:00:00-05:00           0.0
#
# [502 rows x 7 columns]
